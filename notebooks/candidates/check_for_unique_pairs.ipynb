# %% [markdown]
# # Update Script for candidates
# Takes new csv files and old csv files as input and filters pairs from old csv files from the new ones

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Input Files

# %% [markdown]
# ### New CSVs

# %%
new_dir_prefix = "./output/"
new_csv_dirs = [
    f"{new_dir_prefix}candidates_nsp.with_categories.20000.csv",
    f"{new_dir_prefix}candidates_random.with_categories.20000.csv",
    f"{new_dir_prefix}candidates_similarity.with_categories.20000.csv"
]

# %% [markdown]
# ### Old CSVs

# %%
old_dir_prefix = "./old_output/"
old_csv_dirs = [
    f"{old_dir_prefix}candidates_nsp.10000.csv",
    f"{old_dir_prefix}candidates_nsp.with_categories.10000.csv",
    f"{old_dir_prefix}candidates_random.10000.csv",
    f"{old_dir_prefix}candidates_random.with_categories.10000.csv",
    f"{old_dir_prefix}candidates_similarity.10000.csv",
    f"{old_dir_prefix}candidates_similarity.with_categories.10000.csv",
    f"{old_dir_prefix}candidates_nsp.with_categories.10000.03.06.csv",
    f"{old_dir_prefix}candidates_similarity.with_categories.10000.03.06.csv"
]

# %% [markdown]
# ## Run Filter

# %% [markdown]
# ### Create Reference Dataframe of old CSVs

# %%
# Create new large Dataframe
old_csv_list = []
for d in old_csv_dirs:
    old_csv_list.append(pd.read_csv(d))
    
old_df = pd.concat(old_csv_list, ignore_index=True)
old_df
# Out:
#        a_doc_id  a_start  a_end  \
# 0           741       54     84
# 1           741       54     84
# 2           741       85    120
# 3           741       85    120
# 4           736        0     37
# ...         ...      ...    ...
# 32172    152378      164    195
# 32173     99084     2006   2029
# 32174    183714      161    189
# 32175   2089569      106    119
# 32176   2361901      165    199
#
#                                                   a_text  \
# 0      New leadership could prove to be the key to re...
# 1      New leadership could prove to be the key to re...
# 2      The Haaretz had initially reported that former...
# 3      The Haaretz had initially reported that former...
# 4      Hu Jintao, the President of the People's Repub...
# ...                                                  ...
# 32172  Gary Jenkins of Evolution Securities told the ...
# 32173  A protest in Manchester took place outside the...
# 32174  The problem was a metal frame on the tube, whi...
# 32175  This was not the only volcanic eruption in the...
# 32176  The parts are currently undergoing few process...
#
#                                             a_url  \
# 0          https://en.wikinews.org/wiki?curid=741
# 1          https://en.wikinews.org/wiki?curid=741
# 2          https://en.wikinews.org/wiki?curid=741
# 3          https://en.wikinews.org/wiki?curid=741
# 4          https://en.wikinews.org/wiki?curid=736
# ...                                           ...
# 32172   https://en.wikinews.org/wiki?curid=152378
# 32173    https://en.wikinews.org/wiki?curid=99084
# 32174   https://en.wikinews.org/wiki?curid=183714
# 32175  https://en.wikinews.org/wiki?curid=2089569
# 32176  https://en.wikinews.org/wiki?curid=2361901
#
#                                                  a_title  b_doc_id  b_start  \
# 0       Palestinians to elect new president on January 9     88082      184
# 1       Palestinians to elect new president on January 9     75913      297
# 2       Palestinians to elect new president on January 9    102566       68
# 3       Palestinians to elect new president on January 9     20178      120
# 4      President of China lunches with Brazilian Pres...    140463      171
# ...                                                  ...       ...      ...
# 32172  Concern about sovereign debt of some EU member...    131162      159
# 32173  Wikinews international report: "Anonymous" hol...     98498     1129
# 32174  Efforts to cap Deepwater Horizon oil spill del...    207153        0
# 32175                   Volcano erupts in southern Chile    123643      149
# 32176  Malaysia says debris found in Maldives could b...   2364843       73
#
#        b_end                                             b_text  \
# 0        207  The month-long war began in July last year whe...
# 1        320  This will be the largest peacekeeping force ev...
# 2         79  Since 1994, she has held various posts at the ...
# 3        139  A lawsuit was filed in 2000 against the Palest...
# 4        195  Give us this chance and you will not regret it...
# ...      ...                                                ...
# 32172    191  He's saying that the global economy is startin...
# 32173   1149  There are expected to be at least 217 protests...
# 32174     42  Early on Sunday morning, those aboard Developm...
# 32175    160  The volcano had not erupted since a four-month...
# 32176    115  Malaysian officials are currently investigatin...
#
#                                             b_url  \
# 0        https://en.wikinews.org/wiki?curid=88082
# 1        https://en.wikinews.org/wiki?curid=75913
# 2       https://en.wikinews.org/wiki?curid=102566
# 3        https://en.wikinews.org/wiki?curid=20178
# 4       https://en.wikinews.org/wiki?curid=140463
# ...                                           ...
# 32172   https://en.wikinews.org/wiki?curid=131162
# 32173    https://en.wikinews.org/wiki?curid=98498
# 32174   https://en.wikinews.org/wiki?curid=207153
# 32175   https://en.wikinews.org/wiki?curid=123643
# 32176  https://en.wikinews.org/wiki?curid=2364843
#
#                                                  b_title  \
# 0                 Israel says cluster bomb use was legal
# 1                     UN to send troops to Darfur, Sudan
# 2      Zinaida Greceanii nominated Moldovan Prime Min...
# 3      Rhode Island District Court freezes Palestinia...
# 4                   Rio de Janeiro to host 2016 Olympics
# ...                                                  ...
# 32172  Stock markets worldwide rise on hopes of US ec...
# 32173  Church of Scientology: '"Anonymous' will be st...
# 32174  Deepwater Horizon oil well finally dead, autho...
# 32175  Volcano near Anchorage, Alaska erupts, airport...
# 32176  More suspected plane debris washes ashore on M...
#
#                                             a_categories  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32172  Europe,Greece,Portugal,Spain,North America,Uni...
# 32173  California,Canada,Culture and entertainment,Cr...
# 32174  United States,Disasters and accidents,Economy ...
# 32175  disasters and accidents,Chile,South America,Vo...
# 32176  Aviation,Disasters and accidents,Asia,Malaysia...
#
#                                             b_categories
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32172  2008-09 financial crisis,Economy and business,...
# 32173  Crime and law,Internet,Religion,Science and te...
# 32174  North America,United States,Disasters and acci...
# 32175  North America,United States,Alaska,Natural dis...
# 32176  Maldives,Asia,Disasters and accidents,Aviation...
#
# [32177 rows x 14 columns]

# %% [markdown]
# ### Filter New CSVs

# %%
count = 0
# columns to take into account
index_columns = ['a_doc_id', 'a_start', 'a_end', 'b_doc_id', 'b_start', 'b_end']
for d in new_csv_dirs:
    # filter
    df = pd.read_csv(d)
    filtered_df = pd.merge(df, old_df, on=index_columns, how='outer', indicator=True, suffixes=("", "_y"))
    filtered_df = filtered_df[filtered_df['_merge'] == 'left_only']
    filtered_df = filtered_df.drop(columns=['a_text_y', 'a_url_y', 'a_title_y', 'b_text_y', 'b_url_y', 'b_title_y', 'a_categories_y', 'b_categories_y', '_merge'])
    # difference of dfs -> first try, not sufficiant
    #filtered_df = df[~df[index_columns].isin(old_df[index_columns])].dropna().convert_dtypes()
    print(f"Dataset_{count} Length: {len(filtered_df)} ({len(df)-len(filtered_df)} duplicates dropped)")
    # overwrite file
    filtered_df.to_csv(new_csv_dirs[count], index=False)
    count += 1
# Out:
# Dataset_0 Length: 749 (350 duplicates dropped)
# Dataset_1 Length: 1000 (0 duplicates dropped)
# Dataset_2 Length: 1045 (752 duplicates dropped)
