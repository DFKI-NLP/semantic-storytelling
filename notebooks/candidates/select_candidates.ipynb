# %% [markdown]
# # Select candiates for annotation
#
# Select $n=1000$ candidate pairs from each group:
#
# - Random pairs
# - Vector similarity
# - Next sentence prediction
#
# Total $n_{total}=3000$ pairs

# %%
import json
import pandas as pd
import numpy as np
import pickle
from smart_open import open
import os
import sys
import random
import pickle
import logging
from tqdm.notebook import tqdm
from IPython.core.display import display
from collections import defaultdict
import itertools

#sys.path.append(os.path.dirname(os.getcwd()))

from experiments.environment import get_env

logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    level=logging.INFO,
)
logger = logging.getLogger(__name__)

env = get_env()
# Out:
# /data/experiments/raring/semantic_storytelling/malte-candidates/environments
# Environment detected: gpu_server2 (in default.yml)

# %%
n = 20_000
similarity_threshold = 0.92
nsp_threshold = 0.95

data_dir = '/data/experiments/hensel/storytelling-candidates/data/final'
with_categories_data_dir = '/data/experiments/hensel/storytelling-candidates/data/with_categories'

# %%
docs_df = pd.read_csv(os.path.join(with_categories_data_dir, 'meta_data.docs.tsv'), sep='\t', index_col=0, usecols=['doc_id', 'title', 'categories'])
docs_df
# Out:
#                                                      title  \
# doc_id
# 736      President of China lunches with Brazilian Pres...
# 741       Palestinians to elect new president on January 9
# 743       Brazilian delegation returns from Arafat funeral
# 764                 Hearing begins over David Hookes death
# 797      Brazilian soccer player's mother has been kidn...
# ...                                                    ...
# 2909791  Mohsen Fakhrizadeh, leader of Iranian nuclear ...
# 2909805  Former US national security advisor Michael Fl...
# 2909818  Wikinews interviews Sandra Jephcott, Sustainab...
# 2909884  Wikinews interviews Craig Farquharson, Liberal...
# 2910010                            Toddler shot in Ontario
#
#                                                 categories
# doc_id
# 736      Politics and conflicts,South America,Asia,Braz...
# 741      Palestine,Elections,Mahmoud Abbas,Yasser Arafa...
# 743      Palestine,Brazil,Politics and conflicts,Middle...
# 764                Australia,Cricket,Crime and law,Oceania
# 797      South America,Brazil,Football (soccer),Crime a...
# ...                                                    ...
# 2909791  Iran,Asia,Middle East,Nuclear technology,Obitu...
# 2909805  United States,North America,Crime and law,Poli...
# 2909818  Australia,Elections,Climate change,COVID-19,Qu...
# 2909884  Australia,Elections,Queensland,Democracy,Polit...
# 2910010                                            Ontario
#
# [16536 rows x 2 columns]

# %%
category_to_doc_ids = defaultdict(list)
doc_id_to_categories = {}

for doc_id, row in docs_df.iterrows():
    if isinstance(row['categories'], str):
        categories = row['categories'].split(',')
        doc_id_to_categories[doc_id] = set(categories)
        
        for c in categories:
            category_to_doc_ids[c].append(doc_id)
    
logger.info(f'Categories found: {len(category_to_doc_ids)}')
# Out:
# 2021-06-11 14:44:47 - INFO - __main__ -   Categories found: 3334

# %%
min_docs_per_category = 10
max_docs_per_category = 100

needed_categories = {c for c, ds in category_to_doc_ids.items() if min_docs_per_category <= len(ds) <= max_docs_per_category}

logger.info(f'Categories matching criteria: {len(needed_categories)}')
# Out:
# 2021-06-11 14:44:47 - INFO - __main__ -   Categories matching criteria: 1156

# %%
sent_df = pd.read_csv(os.path.join(data_dir, 'meta_data.tsv'), sep='\t')\
    .merge(docs_df, on='doc_id', how='left').set_index('sent_id')
sent_df
# Out:
#              doc_id  start   end  \
# sent_id
# 736-0           736      0    37
# 736-1           736     38    49
# 741-1           741      0    16
# 741-2           741     17    53
# 741-3           741     54    84
# ...             ...    ...   ...
# 2909884-44  2909884   1032  1042
# 2909884-45  2909884   1043  1065
# 2909884-46  2909884   1066  1091
# 2909884-47  2909884   1092  1109
# 2910010-0   2910010      0    11
#
#                                                          text  \
# sent_id
# 736-0       Hu Jintao, the President of the People's Repub...
# 736-1       Lunch was a traditional Brazilian barbecue wit...
# 741-1       Acting president Rawhi Fattuh has announced to...
# 741-2       Futtuh, head of the Palestinian parliament, wa...
# 741-3       New leadership could prove to be the key to re...
# ...                                                       ...
# 2909884-44  Consequently there are water, road and infrast...
# 2909884-45  We aim to make Groom a marginal electorate, if...
# 2909884-46  My approach is to listen to the community and ...
# 2909884-47  The principles of Liberal Democrats are the pr...
# 2910010-0   Delete this line, and start typing your articl...
#
#                                                    url  \
# sent_id
# 736-0           https://en.wikinews.org/wiki?curid=736
# 736-1           https://en.wikinews.org/wiki?curid=736
# 741-1           https://en.wikinews.org/wiki?curid=741
# 741-2           https://en.wikinews.org/wiki?curid=741
# 741-3           https://en.wikinews.org/wiki?curid=741
# ...                                                ...
# 2909884-44  https://en.wikinews.org/wiki?curid=2909884
# 2909884-45  https://en.wikinews.org/wiki?curid=2909884
# 2909884-46  https://en.wikinews.org/wiki?curid=2909884
# 2909884-47  https://en.wikinews.org/wiki?curid=2909884
# 2910010-0   https://en.wikinews.org/wiki?curid=2910010
#
#                                                         title  \
# sent_id
# 736-0       President of China lunches with Brazilian Pres...
# 736-1       President of China lunches with Brazilian Pres...
# 741-1        Palestinians to elect new president on January 9
# 741-2        Palestinians to elect new president on January 9
# 741-3        Palestinians to elect new president on January 9
# ...                                                       ...
# 2909884-44  Wikinews interviews Craig Farquharson, Liberal...
# 2909884-45  Wikinews interviews Craig Farquharson, Liberal...
# 2909884-46  Wikinews interviews Craig Farquharson, Liberal...
# 2909884-47  Wikinews interviews Craig Farquharson, Liberal...
# 2910010-0                             Toddler shot in Ontario
#
#                                                    categories
# sent_id
# 736-0       Politics and conflicts,South America,Asia,Braz...
# 736-1       Politics and conflicts,South America,Asia,Braz...
# 741-1       Palestine,Elections,Mahmoud Abbas,Yasser Arafa...
# 741-2       Palestine,Elections,Mahmoud Abbas,Yasser Arafa...
# 741-3       Palestine,Elections,Mahmoud Abbas,Yasser Arafa...
# ...                                                       ...
# 2909884-44  Australia,Elections,Queensland,Democracy,Polit...
# 2909884-45  Australia,Elections,Queensland,Democracy,Polit...
# 2909884-46  Australia,Elections,Queensland,Democracy,Polit...
# 2909884-47  Australia,Elections,Queensland,Democracy,Polit...
# 2910010-0                                             Ontario
#
# [175720 rows x 7 columns]

# %%
sim_df = pd.read_csv(os.path.join(data_dir, 'similarity_pairs.tsv'), sep='\t', index_col=[0,1])
sim_df
# Out:
#                      similarity
# sent1_id  sent2_id
# 61049-14  45027-2      0.811978
# 2896804-9 7662-5       0.893290
# 8685-1    99779-5      0.888850
# 98820-1   97754-1      0.901756
# 33586-1   33591-3      0.941778
# ...                         ...
# 117956-4  108112-0     0.903401
# 96322-3   151977-10    0.908700
# 123997-9  21575-12     0.923508
# 753804-2  45727-4      0.875747
# 111407-6  83360-3      0.937726
#
# [87860 rows x 1 columns]

# %%
nsp_df = pd.read_csv(os.path.join(data_dir, 'nsp_pairs.csv'), index_col=[0,1])
nsp_df
# Out:
#                    is_next_sentence  is_not_next_sentence
# sent1_id sent2_id
# 736-0    736-1         2.445305e-04          1.028482e-11
#          741-1         1.119650e-08          1.559122e-06
#          741-2         1.085477e-08          1.662852e-06
#          741-3         1.084755e-08          1.551225e-06
#          741-4         1.123367e-08          1.534388e-06
# ...                             ...                   ...
# 741-4    120767-1      9.893848e-09          1.974904e-06
#          120767-2      1.027576e-08          1.819374e-06
#          120767-3      1.013443e-08          1.883872e-06
#          120767-6      9.978086e-09          1.969033e-06
#          120767-7      1.006834e-08          1.999701e-06
#
# [1000001 rows x 2 columns]

# %%
# Random pairs (from different docs)
random_pairs = []
skipped = 0

a_sent_ids = sent_df.index.tolist()
b_sent_ids = sent_df.index.tolist()

# shuffle
random.shuffle(a_sent_ids)
random.shuffle(b_sent_ids)

a_iter = iter(a_sent_ids)
b_iter = iter(b_sent_ids)

while len(random_pairs) < 1000:  # n 
    try:
        a_id = next(a_iter)
        b_id = next(b_iter)

        a = dict(sent_df.loc[a_id])
        b = dict(sent_df.loc[b_id])

        if a['doc_id'] == b['doc_id']:
            skipped += 1
            continue

        # check for categories
        if a['doc_id'] not in doc_id_to_categories or b['doc_id'] not in doc_id_to_categories:
            skipped += 1
            continue

        overlapping_categories = doc_id_to_categories[a['doc_id']] & doc_id_to_categories[b['doc_id']]
        if len(overlapping_categories) < 1:  # not a single overlapping category
            skipped += 1
            continue

        if len(overlapping_categories & needed_categories) < 1:  # categories are not part of needed categories
            skipped += 1
            continue

        pair = {f'a_{k}': a[k] for k in a.keys()}
        pair.update({f'b_{k}': b[k] for k in b.keys()})

        random_pairs.append(pair)
    
    except StopIteration:
        logger.info('done')
        break
    
logger.info(f'Skipped: {skipped:,}; Pairs: {len(random_pairs):,}')
# Out:
# 2021-06-11 14:45:28 - INFO - __main__ -   Skipped: 161,806; Pairs: 1,000

# %%
# Similarity pairs
sim_pairs = []
skipped = 0

for a_id, b_id in sim_df[sim_df.similarity >= similarity_threshold].sample(n=n).index:
    a = dict(sent_df.loc[a_id])
    b = dict(sent_df.loc[b_id])
    
    if a['doc_id'] == b['doc_id']:
        skipped += 1
        continue
    
    # check for categories
    if a['doc_id'] not in doc_id_to_categories or b['doc_id'] not in doc_id_to_categories:
        skipped += 1
        continue
        
    overlapping_categories = doc_id_to_categories[a['doc_id']] & doc_id_to_categories[b['doc_id']]
    if len(overlapping_categories) < 1:  # not a single overlapping category
        skipped += 1
        continue
        
    if len(overlapping_categories & needed_categories) < 1:  # categories are not part of needed categories
        skipped += 1
        continue
    
    pair = {f'a_{k}': a[k] for k in a.keys()}
    pair.update({f'b_{k}': b[k] for k in b.keys()})
    
    sim_pairs.append(pair)
    
logger.info(f'Skipped: {skipped:,}; Pairs: {len(sim_pairs):,}')
# Out:
# 2021-06-11 14:45:33 - INFO - __main__ -   Skipped: 18,203; Pairs: 1,797

# %%
# Next sentence pair
nsp_pairs = []
skipped = 0

for a_id, b_id in nsp_df[((nsp_df.is_next_sentence - nsp_df.is_not_next_sentence) / nsp_df.is_next_sentence) > nsp_threshold].sample(n=n).index:
    a = dict(sent_df.loc[a_id])
    b = dict(sent_df.loc[b_id])
    
    if a['doc_id'] == b['doc_id']:
        skipped += 1
        continue

    # check for categories
    if a['doc_id'] not in doc_id_to_categories or b['doc_id'] not in doc_id_to_categories:
        skipped += 1
        continue
        
    overlapping_categories = doc_id_to_categories[a['doc_id']] & doc_id_to_categories[b['doc_id']]
    if len(overlapping_categories) < 1:  # not a single overlapping category
        skipped += 1
        continue
        
    if len(overlapping_categories & needed_categories) < 1:  # categories are not part of needed categories
        skipped += 1
        continue
        
    pair = {f'a_{k}': a[k] for k in a.keys()}
    pair.update({f'b_{k}': b[k] for k in b.keys()})
    
    nsp_pairs.append(pair)
    
logger.info(f'Skipped: {skipped:,}; Pairs: {len(nsp_pairs):,}')
# Out:
# 2021-06-11 14:45:37 - INFO - __main__ -   Skipped: 18,901; Pairs: 1,099

# %%
len(random_pairs), len(sim_pairs), len(nsp_pairs)
# Out:
# (1000, 1797, 1099)

# %%
# write to disk
write_dir = "./output/"
pd.DataFrame(random_pairs).to_csv(os.path.join(write_dir, f'candidates_random.with_categories.{n}.csv'), index=False)
pd.DataFrame(sim_pairs).to_csv(os.path.join(write_dir, f'candidates_similarity.with_categories.{n}.csv'), index=False)
pd.DataFrame(nsp_pairs).to_csv(os.path.join(write_dir, f'candidates_nsp.with_categories.{n}.csv'), index=False)


#pd.DataFrame(random_pairs).to_csv(os.path.join(data_dir, f'candidates_random.{n}.csv'), index=False)
#pd.DataFrame(sim_pairs).to_csv(os.path.join(data_dir, f'candidates_similarity.{n}.csv'), index=False)
#pd.DataFrame(nsp_pairs).to_csv(os.path.join(data_dir, f'candidates_nsp.{n}.csv'), index=False)

# %%
random_pairs[:10]
# Out:
# [{'a_doc_id': 47348,
#   'a_start': 92,
#   'a_end': 121,
#   'a_text': "The President's Emergency Plan for AIDS Relief has done a great deal of good, and President Bush and his team deserve a lot of credit for it, Gates said.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=47348',
#   'a_title': 'AIDS Conference: Clinton and Gates defend Bush program',
#   'a_categories': 'World,United States,Canada,Health,George W. Bush,AIDS,Bill Clinton,Bill Gates,Prostitution',
#   'b_doc_id': 102849,
#   'b_start': 1453,
#   'b_end': 1473,
#   'b_text': ":'Melody Thomas Scott': One would think so, but I have not yet seen another show equal to our production values.",
#   'b_url': 'https://en.wikinews.org/wiki?curid=102849',
#   'b_title': "Popular soap opera 'The Young and the Restless' celebrates 35 years on the air",
#   'b_categories': 'North America,United States,Culture and entertainment,Media,Television,Mike Halterman (Wikinewsie),Prostitution'},
#  {'a_doc_id': 259826,
#   'a_start': 217,
#   'a_end': 234,
#   'a_text': "Several Asian countries also said bin Laden's death was a step forward in the war against terrorism.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=259826',
#   'a_title': 'World leaders react to death of Osama bin Laden',
#   'a_categories': 'Osama bin Laden,Politics and conflicts,Al-Qaeda,Pakistan,United States,United Kingdom,Italy,Singapore,Malaysia,China,Japan,United Nations,NATO,Barack Obama,France,Germany,Australia,Mike Smith (Wikinewsie),Asia,North America,Europe,Oceania,Ban Ki-moon,David Cameron,Silvio Berlusconi,Angela Merkel,Julia Gillard,Nicolas Sarkozy',
#   'b_doc_id': 143693,
#   'b_start': 77,
#   'b_end': 97,
#   'b_text': 'Afghan Defence Ministry spokesman, Gen Mohammad Zahir Azimi, said that the airstrike hit a base housing NATO and Afghan troops.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=143693',
#   'b_title': 'NATO airstrike kills seven Afghan security forces members',
#   'b_categories': 'Politics and conflicts,Asia,NATO,Jonathan Alexandr Ledbury-Romanov (Wikinewsie),Missing persons,Afghanistan'},
#  {'a_doc_id': 96767,
#   'a_start': 153,
#   'a_end': 170,
#   'a_text': 'After saying that she added But the work is far from finished, the dream is not fulfilled.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=96767',
#   'a_title': 'Martin Luther King day commemorated by US citizens',
#   'a_categories': 'United States,Barack Obama,Politics and conflicts,Hillary Clinton,George W. Bush,Mike Huckabee,John Edwards,Mitt Romney,Democratic Party (United States),Republican Party (United States)',
#   'b_doc_id': 120071,
#   'b_start': 204,
#   'b_end': 240,
#   'b_text': 'If someone wants to talk with us in the language that Bush used, he said, even if he uses new words, our response will be the same that we gave to Bush during the past years.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=120071',
#   'b_title': "Iran's Ahmadinejad wants change in US policies, not 'tactics'",
#   'b_categories': 'Asia,Middle East,Iran,North America,United States,Politics and conflicts,Mahmoud Ahmadinejad,George W. Bush,Hillary Clinton,Barack Obama,Nuclear proliferation,Nuclear power'},
#  {'a_doc_id': 2798451,
#   'a_start': 1557,
#   'a_end': 1569,
#   'a_text': 'That platform/party folded in May 2012 because it ran out of money.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=2798451',
#   'a_title': 'On the campaign trail in the USA, August 2016',
#   'a_categories': '2016 United States presidential election,United States,North America,Politics and conflicts,Twitter,Facebook,WikiLeaks,Libertarian Party (United States),Green Party of the United States,Constitution Party (United States),Reform Party of the United States of America,American Independent Party,Peace and Freedom Party,Americans Elect,Democratic Party (United States),Republican Party (United States),Barack Obama,Gary Johnson,Donald Trump,Hillary Clinton,Bernie Sanders,Laurence Kotlikoff,Virgil Goode,Jeb Bush,Roger Stone,Ku Klux Klan,Louisiana,California,Florida,Nevada,New Hampshire,Mexico,Russia,Jill Stein,Mike Pence,Enrique Peña Nieto,Russian involvement in the 2016 US presidential election,Boston University,Paul Manafort,Lesser-Known Candidates Forum,Reno, Nevada,William Weld,Joe Scarborough',
#   'b_doc_id': 123636,
#   'b_start': 194,
#   'b_end': 209,
#   'b_text': 'State officials said the rules are damaging a major pillar of the New Jersey economy.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=123636',
#   'b_title': 'New Jersey officials: Stimulus bill hurting Atlantic City casinos',
#   'b_categories': 'Barack Obama|Barack Obama,Barack Obama,Culture and entertainment,Economy and business,Las Vegas,North America,Nevada,New Jersey,Poker,Politics and conflicts,United States,Harry Reid,Tourism,Atlantic City, New Jersey'},
#  {'a_doc_id': 108057,
#   'a_start': 363,
#   'a_end': 412,
#   'a_text': "The report also says that the close proximity of all London's airports to the Meridian Line can lead crews to make such co-ordinate entry errors of this nature, and that as LOT rarely uses airports to the West of the line they will usually only deal with Easterly co-ordinates.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=108057',
#   'a_title': 'Report finds LOT Airlines plane was lost over London due to pilot error',
#   'a_categories': 'Disasters and accidents,Europe,Poland,United Kingdom,London,Transport,Aviation,Iain Macdonald (Wikinewsie),Air Accidents Investigation Branch,Heathrow Airport',
#   'b_doc_id': 159986,
#   'b_start': 291,
#   'b_end': 311,
#   'b_text': 'He had dismissed these allegations as being ridiculous and said For Serbia, anyone who defended our country must be arrested.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=159986',
#   'b_title': 'Former Bosnian president arrested in London',
#   'b_categories': 'Adi4094 (WWC2010),Writing contest 2010,Serbia,Bosnia and Herzegovina,United Kingdom,Military,Crime and law,War crimes,Politics and conflicts,Human rights,Metropolitan Police,Foreign and Commonwealth Office,Yugoslavia,Bosnian War,London,Heathrow Airport'},
#  {'a_doc_id': 120875,
#   'a_start': 585,
#   'a_end': 626,
#   'a_text': 'According to Nelson Bien, head of the Fisheries Resource and Management Division of BFAR Region III, a necropsy by BFAR, the provincial veterinarian, and veterinarians from the Ocean Adventure in Subic Freeport has traced the cause of their death to drowning.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=120875',
#   'a_title': '500 stranded melon-headed whales rescued in Philippine bay',
#   'a_categories': 'Philippines,Disasters and accidents,Environment,Culture and entertainment,Economy and business,Animal rights,Asia,Earthquakes,Greenpeace,Hawaii,Ireland,Science and technology,Wackynews,Manila,Luzon,South China Sea,Museums,Species endangerment,Biology,Marine science,International Union for the Conservation of Nature,Whales,Mindanao',
#   'b_doc_id': 53301,
#   'b_start': 146,
#   'b_end': 162,
#   'b_text': 'Dickey has said that Forzie is stored in a freezer awaiting a taxidermist to stuff it.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=53301',
#   'b_title': 'Malformed chicken dies in New Zealand',
#   'b_categories': 'New Zealand,Oceania,Wackynews,Animal rights'},
#  {'a_doc_id': 171413,
#   'a_start': 22,
#   'a_end': 49,
#   'a_text': "U.S. President Barack Obama and Russian President Dmitri Medvedev have signed a treaty to reduce their countries' nuclear stockpiles by 25 to 30 percent over seven years.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=171413',
#   'a_title': 'Obama, Medvedev sign treaty cutting nuclear stockpiles',
#   'a_categories': 'Nuclear proliferation,Nuclear weapons,United States,Russia,North America,Barack Obama,Asia,Europe,Dmitry Medvedev,Prague,Czech Republic,Soviet Union,Politics and conflicts,United Nations Security Council,Russian State Duma,George H. W. Bush,Sergey Lavrov,Ronald Reagan',
#   'b_doc_id': 310400,
#   'b_start': 1054,
#   'b_end': 1069,
#   'b_text': "'Of the candidates currently running for the Republican Party nomination, which do you most admire?'",
#   'b_url': 'https://en.wikinews.org/wiki?curid=310400',
#   'b_title': 'Wikinews interviews Darcy Richardson, Democratic Party presidential challenger to Barack Obama',
#   'b_categories': 'Pennsylvania,Florida,New Hampshire,Barack Obama,Interview,Missouri,Democratic Party (United States),Republican Party (United States),Buddy Roemer,Fred Karger,Gary Johnson,Darcy Richardson,Ron Paul,Jacksonville, Florida,Bernie Sanders,Boston Tea Party (political party),Citizens Party (United States, 1980s),Ronald Reagan,Constitution of the United States'},
#  {'a_doc_id': 87694,
#   'a_start': 173,
#   'a_end': 212,
#   'a_text': "Created in the era of long-gone acts like N*SYNC, Aaron Carter, and the A*Teens, and when Britney Spears wasn't nightly fodder for talk show hosts, JUMP5 managed to stay active and for the most part together throughout the years.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=87694',
#   'a_title': 'Jump5 plays their last concert, disbanding after nine years',
#   'a_categories': 'Culture and entertainment,Music,North America,United States,Tennessee,Religion,Christianity',
#   'b_doc_id': 128964,
#   'b_start': 27,
#   'b_end': 40,
#   'b_text': 'McNair was still married to another woman at the time of his death.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=128964',
#   'b_title': 'Former NFL quarterback Steve McNair shot dead',
#   'b_categories': 'North America,United States,Maryland,Tennessee,Crime and law,Sports,Football (American),National Football League,Baltimore, Maryland'},
#  {'a_doc_id': 2846899,
#   'a_start': 621,
#   'a_end': 645,
#   'a_text': "In the 80th minute, Morocco won a corner, and a minute later, they scored their second goal of the game, as Faycal Fajr's assist.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=2846899',
#   'a_title': 'FIFA World Cup 2018 day 12, 13, 14, 15: Iran, Nigeria, Germany, Senegal out of the tournament',
#   'a_categories': 'Saudi Arabia,Egypt,Uruguay,Luis Suárez,Denis Cheryshev,Iran,Portugal,Cristiano Ronaldo,Spain,Morocco,Australia,Peru,Denmark,France,Iceland,Croatia,Ivan Rakitić,Luka Modrić,Nigeria,Argentina,Lionel Messi,Serbia,Brazil,Philippe Coutinho,Neymar da Silva Santos Júnior,Switzerland,Costa Rica,South Korea,Germany,Mexico,Sweden,Manuel Neuer,Mats Hummels,Toni Kroos,Thomas Müller,England,Belgium,Thibaut Courtois,Eden Hazard,Paul Pogba,Antoine Griezmann,Axel Witsel,Romelu Lukaku,Panama,Tunisia,Japan,Poland,Robert Lewandowski,Senegal,Colombia,Gonzalo Higuaín\u200e,Sergio Agüero\u200e,2018 FIFA World Cup,2018 FIFA World Cup match reports,Football (soccer),Football match reports,Sports,Europe,Asia,Africa,Middle East,South America,North America,Sergio Busquets,Jordi Alba,Gerard Piqué,Diego Costa,Dani Carvajal,Mohamed Salah,Képler Laveran Lima Ferreira,Andrés Iniesta,Edinson Cavani,Ivan Perišić,Acagastya (Wikinewsie),Mateo Kovačić,Mesut Özil,Xherdan Shaqiri,Marco Reus,David de Gea,Ricardo Quaresma,Marcus Rashford',
#   'b_doc_id': 7074,
#   'b_start': 57,
#   'b_end': 69,
#   'b_text': 'NATO chief World Trade Center, but were brought home by November 2002.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=7074',
#   'b_title': 'Australia, NATO enhance ties',
#   'b_categories': 'Politics and conflicts,Australia,NATO,Brussels,Belgium,Europe,Oceania,Afghanistan,Asia,Weapons of mass destruction'},
#  {'a_doc_id': 104062,
#   'a_start': 31,
#   'a_end': 62,
#   'a_text': "The family blames the Church of Scientology for her death and decided to go public with the story, after the test results and a suicide note were discovered after Ballo's death.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=104062',
#   'a_title': "Family blames Scientology for daughter's death",
#   'a_categories': 'Europe,France,Norway,Religion,Scientology,Health,Crime and law,Politics and conflicts,Mental health,Suicide',
#   'b_doc_id': 99084,
#   'b_start': 1689,
#   'b_end': 1712,
#   'b_text': 'There were a number of minor incidents involving protesters (who were quickly distanced by the majority crowd), but no major violations took place.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=99084',
#   'b_title': 'Wikinews international report: "Anonymous" holds anti-Scientology protests worldwide',
#   'b_categories': 'California,Canada,Culture and entertainment,Crime and law,Florida,Internet,London,Los Angeles, California,New York,New York, New York,Buffalo, New York,Australia,Arizona,Texas,Religion,Science and technology,Scientology,Project Chanology,World,Edinburgh,Phoenix, Arizona,North America,Scotland,England,Europe,Oceania,Lisa McPherson,Brussels,Photo essays,Anonymous (group),Brisbane,Queensland,Pennsylvania,Pittsburgh,San Diego, California,Portland, Oregon,Honolulu, Hawaii,Hawaii,Atlanta, Georgia,Georgia (U.S. state)'}]

# %%
sim_pairs[:10]
# Out:
# [{'a_doc_id': 161838,
#   'a_start': 0,
#   'a_end': 38,
#   'a_text': 'According to witness and media reports, at least two hundred people in Nigeria have been killed after pastoralists and villagers clashed near the city of , which has been the source of repeated tension between Christians and Muslims.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=161838',
#   'a_title': 'Clashes in Nigeria kill hundreds, troops on alert',
#   'a_categories': 'Tempodivalse (WWC2010),Writing contest 2010,Disasters and accidents,Crime and law,Africa,Goodluck Jonathan,Nigeria',
#   'b_doc_id': 177003,
#   'b_start': 0,
#   'b_end': 23,
#   'b_text': 'Fresh violence has broken out in the central Nigerian city of  earlier today, killing at least five people, according to witness reports.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=177003',
#   'b_title': 'Five dead after continuing violence in Nigeria',
#   'b_categories': 'Africa,Politics and conflicts,Crime and law,Nigeria,Religion,Islam,Christianity'},
#  {'a_doc_id': 108775,
#   'a_start': 0,
#   'a_end': 37,
#   'a_text': "A file photograph of MugabeRobert Mugabe, the Zimbabwean president who has recently been widely criticized by world leaders, has claimed the current results show that he will have a 'sweeping victory' in the unopposed presidential run-off elections.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=108775',
#   'a_title': "Mugabe claims 'sweeping victory' of Zimbawe election",
#   'a_categories': 'Africa,Zimbabwe,Politics and conflicts,Elections,Robert Mugabe,United Nations,Ban Ki-moon,Harare',
#   'b_doc_id': 108112,
#   'b_start': 0,
#   'b_end': 50,
#   'b_text': 'Zimbabwean President Robert Mugabe, who is slated to face opposition leader Morgan Tsvangirai in a run-off election on June 27, said today that the opposition would never govern Zimbabwe as long as he is alive, vowing to go to war if the Movement for Democratic Change (MDC) wins the election.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=108112',
#   'b_title': "Mugabe is 'prepared to fight' if Zimbabwe elects opposition",
#   'b_categories': 'Africa,Zimbabwe,Politics and conflicts,Elections,Robert Mugabe,United Kingdom,Gordon Brown,Movement for Democratic Change,Morgan Tsvangirai'},
#  {'a_doc_id': 100545,
#   'a_start': 110,
#   'a_end': 161,
#   'a_text': 'The statement added that “we the BBC realise that not everyone enjoys watching sport but there is undeniably a large section of our audience who do.” The statement also said that  the BBC should provide content which will be enjoyed by the “large section” of society who enjoy watching sport.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=100545',
#   'a_title': 'Sports-heavy broadcast day for BBC One receives complaints; BBC responds',
#   'a_categories': 'United Kingdom,BBC,Culture and entertainment,Sports',
#   'b_doc_id': 43516,
#   'b_start': 277,
#   'b_end': 409,
#   'b_text': "A question within the FAQs for one of the more recent selections of clips suggests that this isn’t possible, saying “during this pilot phase material released under the terms of the Creative Archive Licence cannot be used outside the UK - therefore, unless a website has its use restricted to the UK only, content from the 'Regions on Film' archive cannot be published on it.” “We want people to make full use of this content, whether they cut and paste it or whether they share it, and we completely accept that we’ve got a bit of a contradiction at the moment by saying UK-only and yet encouraging people to put it on their sites to share it with others, because you can’t expect people to have geo-IP restriction technology,” admits Mr Gerhardt.",
#   'b_url': 'https://en.wikinews.org/wiki?curid=43516',
#   'b_title': 'Interview with BBC Creative Archive project leader',
#   'b_categories': 'United Kingdom,Europe,Culture and entertainment,Television,Radio,BBC,Creative Commons'},
#  {'a_doc_id': 16459,
#   'a_start': 0,
#   'a_end': 37,
#   'a_text': "Scotland Yard issued a statement that Jean Charles de Menezes, the 27-year-old Brazilian electrician shot to death yesterday by police in a London Underground station was not connected to Thursday's bombings and called the incident a tragedy.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=16459',
#   'a_title': 'Man shot on London Underground unconnected to bombing, says Scotland Yard',
#   'a_categories': 'Crime and law,London,United Kingdom,Brazil,Metropolitan Police,London Underground,Independent Police Complaints Commission',
#   'b_doc_id': 16299,
#   'b_start': 68,
#   'b_end': 107,
#   'b_text': 'Just after 6pm BST police arrested a man at the Snow Hill rail station in Birmingham under Section 44 of the Terrorism Act. The station was evacuated and cordoned off because of two suspicious suitcases found at the station.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=16299',
#   'b_title': 'Man arrested in connection with July 21 London bomb attempts',
#   'b_categories': 'Crime and law,Europe,United Kingdom,Metropolitan Police'},
#  {'a_doc_id': 79874,
#   'a_start': 436,
#   'a_end': 463,
#   'a_text': 'Wales are second with five points, ahead of Fiji on points difference, while Japan have one point and Canada are bottom of the group with no points.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=79874',
#   'a_title': '2007 Rugby World Cup: New Zealand, Australia and Ireland win',
#   'a_categories': 'Sports,Rugby,Rugby World Cup,New Zealand,Portugal,Wales,Australia,Ireland,Georgia (country),Cardiff, Wales',
#   'b_doc_id': 80435,
#   'b_start': 94,
#   'b_end': 114,
#   'b_text': 'France lead Pool D with ten points, while Ireland are third on points difference behind Argentina, both with nine points.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=80435',
#   'b_title': '2007 Rugby World Cup: France 25 - 3 Ireland',
#   'b_categories': 'Sports,Rugby,Rugby World Cup,France,Ireland,Europe'},
#  {'a_doc_id': 181904,
#   'a_start': 0,
#   'a_end': 36,
#   'a_text': 'Gordon Brown became Prime Minister in 2007  In the latest developments in discussions between the Liberal Democrats and the two largest parties, Gordon Brown has announced his resignation as Labour Party leader and Prime Minister.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=181904',
#   'a_title': 'UK elections: Gordon Brown offers resignation to secure Labour-Liberal coalition',
#   'a_categories': 'Gordon Brown,Elections,Politics and conflicts,Europe,Nick Clegg,Labour Party (UK),Scottish National Party,Plaid Cymru,Downing Street,United Kingdom,Liberal Democrats (UK),Conservative Party (UK),UK Parliament',
#   'b_doc_id': 170617,
#   'b_start': 164,
#   'b_end': 199,
#   'b_text': 'For the first time in a UK election, there will be three televised debates between the main party leaders\xa0— Gordon Brown for Labour, David Cameron for the Conservatives, and Nick Clegg for the Liberal Democrats.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=170617',
#   'b_title': 'UK Prime Minister announces date for general election',
#   'b_categories': 'Elections,Politics and conflicts,United Kingdom,Gordon Brown,Europe,Nick Clegg'},
#  {'a_doc_id': 45168,
#   'a_start': 42,
#   'a_end': 65,
#   'a_text': 'The clashes follow a Hezbollah raid into Israel which they called Truthful Promise in which Hezbollah claimed to have captured two Israeli soldiers.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=45168',
#   'a_title': 'Day of attacks continue in Israel and Lebanon',
#   'a_categories': 'Politics and conflicts,Lebanon,Israel,Middle East,2006 Israel-Lebanon conflict,Condoleezza Rice,Hezbollah,Mahmoud Ahmadinejad,Margaret Beckett,Haifa,Museums,Shia Islam,Arab League',
#   'b_doc_id': 45184,
#   'b_start': 161,
#   'b_end': 190,
#   'b_text': 'The government in Beirut has said it accepts no responsibility for what Hezbollah claimed was the capture of two Israeli soldiers, in an attack which injured six Israeli civilians.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=45184',
#   'b_title': 'Israeli vessels enter Lebanese waters to enforce blockade',
#   'b_categories': 'Politics and conflicts,Lebanon,Israel,Middle East,2006 Israel-Lebanon conflict,Hezbollah'},
#  {'a_doc_id': 2897504,
#   'a_start': 1734,
#   'a_end': 1751,
#   'a_text': 'We know the quantity of gas and dust that is there, and which will form planets anyway.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=2897504',
#   'a_title': 'Astronomer Anthony Boccaletti discusses observation of birth of potential exoplanet with Wikinews',
#   'a_categories': 'Astronomy,Science and technology,Space,France,European Southern Observatory,Exoplanets,Europe,Physics,Chile,Paris,Very Large Telescope,Acagastya (Wikinewsie)',
#   'b_doc_id': 2907434,
#   'b_start': 716,
#   'b_end': 764,
#   'b_text': "'How would you define what a 'biosignature gas' is and what is its advantage in looking for life in exoplanets compared to other forms?'  A biosignature gas is one that is produced by life, can accumulate in a planetary atmosphere, and be detected with remote space telescopes.",
#   'b_url': 'https://en.wikinews.org/wiki?curid=2907434',
#   'b_title': "'Earth-based life can survive in hydrogen-rich atmospheres': MIT professor Dr Seager tells Wikinews about her research on organisms thriving in oxygen-less environment",
#   'b_categories': 'United States,North America,Massachusetts,Massachusetts Institute of Technology,Astronomy,Space,Science and technology,Biology,Chemistry,Exoplanets'},
#  {'a_doc_id': 127789,
#   'a_start': 104,
#   'a_end': 143,
#   'a_text': 'The second round series against the Washington Capitals featured a highly-touted individual matchup, as the Penguins young star Sidney Crosby matched skills against Alexander Ovechkin of the Capitals; it took the Penguins all seven games to win that series.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=127789',
#   'a_title': 'Pittsburgh Penguins win Stanley Cup',
#   'a_categories': 'United States,North America,Michigan,Pittsburgh,Pennsylvania,Sports,National Hockey League,Ice hockey',
#   'b_doc_id': 105308,
#   'b_start': 417,
#   'b_end': 448,
#   'b_text': 'The Eastern Conference Finals, meanwhile, is an all-Pennsylvania matchup, as the Pittsburgh Penguins, who clinched their series with a 3-2 overtime victory on Sunday, face off against the rival Philadelphia Flyers.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=105308',
#   'b_title': 'NHL: Stars advance in eighth-longest playoff game',
#   'b_categories': 'North America,United States,Culture and entertainment,Sports,National Hockey League,Pennsylvania,Pittsburgh,Ice hockey'},
#  {'a_doc_id': 58880,
#   'a_start': 141,
#   'a_end': 163,
#   'a_text': 'The World Health Organization is also stating that the three cases may be human to human transmission, but further tests are needed.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=58880',
#   'a_title': 'H5N1 Avian Flu virus mutates; shows resistance to drug',
#   'a_categories': 'World,Avian Flu,Health,Disease,Infectious disease,Africa,Egypt,Influenza,Oseltamivir',
#   'b_doc_id': 47217,
#   'b_start': 322,
#   'b_end': 368,
#   'b_text': 'The confirmatory testing underway at NVSL will clarify whether one or more strains of the virus are present, the specific subtype, as well as pathogenicity, said that statement but also said that it could take up to two weeks and will be made public when completed.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=47217',
#   'b_title': 'Suspected low pathogenic H5N1 Bird Flu virus found in the United States',
#   'b_categories': 'United States,Avian Flu,Michigan,Health,August 14, 2006,Influenza'}]

# %%
nsp_pairs[:10]
# Out:
# [{'a_doc_id': 741,
#   'a_start': 17,
#   'a_end': 53,
#   'a_text': 'Futtuh, head of the Palestinian parliament, was sworn in hours after the death of Yasser Arafat on Thursday, and Palestinian Basic Law dictates that he may only serve up to two months before elections are held.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 4301,
#   'b_start': 113,
#   'b_end': 138,
#   'b_text': "The groups appear to have come to an agreement that they should continue to observe a month's calm, as agreed with Abbas in late January.",
#   'b_url': 'https://en.wikinews.org/wiki?curid=4301',
#   'b_title': 'Hamas dampens Palestinian-Israeli truce',
#   'b_categories': 'Middle East,Israel,Palestine,Politics and conflicts,Mahmoud Abbas,Hamas,Palestinian National Authority,Sharm el-Sheikh,Palestinian Islamic Jihad'},
#  {'a_doc_id': 741,
#   'a_start': 54,
#   'a_end': 84,
#   'a_text': 'New leadership could prove to be the key to revitalizing the peace process in the Middle East, as both Israel and the United States had refused to work with Arafat.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 110270,
#   'b_start': 164,
#   'b_end': 189,
#   'b_text': 'Hamas would not blame the rival Fatah faction directly for the incident but implied its involvement, issuing a statement blaming members of the fugitive party.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=110270',
#   'b_title': 'Six year old girl and five others killed, Hamas arrests 200 Palestinians',
#   'b_categories': 'Disasters and accidents,Middle East,Politics and conflicts,Gaza Strip,Mahmoud Abbas,Hamas,Palestinian National Authority,Fatah,Palestine'},
#  {'a_doc_id': 741,
#   'a_start': 54,
#   'a_end': 84,
#   'a_text': 'New leadership could prove to be the key to revitalizing the peace process in the Middle East, as both Israel and the United States had refused to work with Arafat.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 15169,
#   'b_start': 0,
#   'b_end': 22,
#   'b_text': 'A coordinated Palestinian attack of four Qassam rockets and more than 20 mortar shells took place around 6 p.m. IST (+3 UTC).',
#   'b_url': 'https://en.wikinews.org/wiki?curid=15169',
#   'b_title': 'Palestinian rocket attack kills Israeli woman',
#   'b_categories': 'Politics and conflicts,Middle East,Israel,Palestine,Hamas,Israel Defense Forces,Palestinian National Authority,Fatah,Palestinian Islamic Jihad'},
#  {'a_doc_id': 736,
#   'a_start': 0,
#   'a_end': 37,
#   'a_text': "Hu Jintao, the President of the People's Republic of China had lunch today with the President of Brazil, Luiz Inácio Lula da Silva, at the Granja do Torto, the President's country residence in the Brazilian Federal District.",
#   'a_url': 'https://en.wikinews.org/wiki?curid=736',
#   'a_title': 'President of China lunches with Brazilian President',
#   'a_categories': 'Politics and conflicts,South America,Asia,Brazil,China,India,Hu Jintao,Luiz Inácio Lula da Silva,Dilma Rousseff,Petrobras',
#   'b_doc_id': 6104,
#   'b_start': 1686,
#   'b_end': 1696,
#   'b_text': '*Brazilian government have already said that it is against terrorism.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=6104',
#   'b_title': "FARC and Brazilian Workers' Party:the general didn't tell the truth, says former Abin superior to Veja",
#   'b_categories': 'Politics and conflicts,Crime and law,South America,Brazil,Published,Luiz Inácio Lula da Silva,Magazines'},
#  {'a_doc_id': 736,
#   'a_start': 38,
#   'a_end': 49,
#   'a_text': 'Lunch was a traditional Brazilian barbecue with different kinds of meat.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=736',
#   'a_title': 'President of China lunches with Brazilian President',
#   'a_categories': 'Politics and conflicts,South America,Asia,Brazil,China,India,Hu Jintao,Luiz Inácio Lula da Silva,Dilma Rousseff,Petrobras',
#   'b_doc_id': 6104,
#   'b_start': 1665,
#   'b_end': 1676,
#   'b_text': 'Recently Brazil and Venezuela assigned agreements of economic and military cooperation.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=6104',
#   'b_title': "FARC and Brazilian Workers' Party:the general didn't tell the truth, says former Abin superior to Veja",
#   'b_categories': 'Politics and conflicts,Crime and law,South America,Brazil,Published,Luiz Inácio Lula da Silva,Magazines'},
#  {'a_doc_id': 741,
#   'a_start': 17,
#   'a_end': 53,
#   'a_text': 'Futtuh, head of the Palestinian parliament, was sworn in hours after the death of Yasser Arafat on Thursday, and Palestinian Basic Law dictates that he may only serve up to two months before elections are held.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 183104,
#   'b_start': 53,
#   'b_end': 91,
#   'b_text': "He also requested that an Israeli soldier captured by Hamas in 2006, Gilad Shalit, be released, although this was refused by Hamas, who says that Shalit wouldn't be released unless there was an honourable prisoner exchange with Israel.",
#   'b_url': 'https://en.wikinews.org/wiki?curid=183104',
#   'b_title': 'Russian meeting with Hamas provokes criticism from Israel',
#   'b_categories': 'Tempodivalse (Wikinewsie),Writing Contests/May 2010,Hamas,Russia,Israel,Israel/Palestine Conflict,Middle East,Syria,Europe,Bashar al-Assad,Fatah,Politics and conflicts'},
#  {'a_doc_id': 741,
#   'a_start': 17,
#   'a_end': 53,
#   'a_text': 'Futtuh, head of the Palestinian parliament, was sworn in hours after the death of Yasser Arafat on Thursday, and Palestinian Basic Law dictates that he may only serve up to two months before elections are held.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 9098,
#   'b_start': 49,
#   'b_end': 62,
#   'b_text': 'The Russian President was cheered by the Palestinian crowd prior to the conference.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=9098',
#   'b_title': 'Putin pledges to help Palestinians',
#   'b_categories': 'Russia,Middle East,Mahmoud Abbas,Vladimir Putin,Ramallah'},
#  {'a_doc_id': 741,
#   'a_start': 54,
#   'a_end': 84,
#   'a_text': 'New leadership could prove to be the key to revitalizing the peace process in the Middle East, as both Israel and the United States had refused to work with Arafat.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 14946,
#   'b_start': 191,
#   'b_end': 211,
#   'b_text': 'The Israeli government asked the PA to arrest the wanted terrorists numerous times, according to high-ranking officers in the IDF.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=14946',
#   'b_title': 'Israeli army reoccupies Tulkarem in West Bank',
#   'b_categories': 'Israel,Middle East,Palestinian National Authority,Israel/Palestine Conflict,West Bank,Palestinian Islamic Jihad,Suicide attacks'},
#  {'a_doc_id': 741,
#   'a_start': 85,
#   'a_end': 120,
#   'a_text': 'The Haaretz had initially reported that former prime minister Mahmoud Abbas was selected by the Fatah central committee as their candidate for president, but Abbas has denied this, saying, the matter is still being discussed.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 4301,
#   'b_start': 32,
#   'b_end': 50,
#   'b_text': 'Hamas said that although the Palestinian leaders had announced a truce, the organisation was not bound to it.',
#   'b_url': 'https://en.wikinews.org/wiki?curid=4301',
#   'b_title': 'Hamas dampens Palestinian-Israeli truce',
#   'b_categories': 'Middle East,Israel,Palestine,Politics and conflicts,Mahmoud Abbas,Hamas,Palestinian National Authority,Sharm el-Sheikh,Palestinian Islamic Jihad'},
#  {'a_doc_id': 741,
#   'a_start': 54,
#   'a_end': 84,
#   'a_text': 'New leadership could prove to be the key to revitalizing the peace process in the Middle East, as both Israel and the United States had refused to work with Arafat.',
#   'a_url': 'https://en.wikinews.org/wiki?curid=741',
#   'a_title': 'Palestinians to elect new president on January 9',
#   'a_categories': 'Palestine,Elections,Mahmoud Abbas,Yasser Arafat,Fatah,Middle East,Palestinian National Authority',
#   'b_doc_id': 14839,
#   'b_start': 315,
#   'b_end': 352,
#   'b_text': "In light of the bombing, Israeli defence minister, Shaul Mofaz, cancelled a meeting with the Palestinian minister for civil affairs, Mohammed Dahlan, set for this evening to coordinate various issues regarding Israel's withdrawal from the Gaza Strip.",
#   'b_url': 'https://en.wikinews.org/wiki?curid=14839',
#   'b_title': 'Suicide attack hits mall in Netanya, Israel',
#   'b_categories': 'Israel,Middle East,Ariel Sharon,Palestinian National Authority,Palestinian Islamic Jihad,Suicide attacks'}]
