# %% [markdown]
# # Properties

# %%
input_path = "./candidates/output/candidates_similarity.with_categories.20000.csv"
output_path = "./similarity_categories_11-6-2021.xmi"

# %% [markdown]
# # Install

# %% [markdown]
# ## Install Package to write CAS XMI files

# %% [markdown]
# See https://github.com/dkpro/dkpro-cassis

# %%
#pip install dkpro-cassis
# Out:
# Requirement already satisfied: dkpro-cassis in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: lxml>=4.5.0 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (4.6.2)
# Requirement already satisfied: attrs>=19.3.0 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (20.3.0)
# Requirement already satisfied: sortedcontainers>=2.1.0 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (2.3.0)
# Requirement already satisfied: toposort>=1.5 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (1.6)
# Requirement already satisfied: more-itertools>=8.2.0 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (8.7.0)
# Requirement already satisfied: deprecation>=2.0.7 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (2.1.0)
# Requirement already satisfied: importlib_resources>=1.0.2 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from dkpro-cassis) (5.1.0)
# Requirement already satisfied: packaging in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from deprecation>=2.0.7->dkpro-cassis) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from packaging->deprecation>=2.0.7->dkpro-cassis) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Installing Pandas for better csv/tsv support

# %%
#pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (1.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/mika/.pyenv/versions/3.8.7/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Skript

# %% [markdown]
# ## Import TSV Input Files

# %%
import pandas as pd
segments = pd.read_csv(input_path,sep=',')

# %%
segments
# Out:
#       a_doc_id  a_start  a_end  \
# 0       148545      236    254
# 1       320196     1583   1637
# 2       130602      325    366
# 3       201658      101    132
# 4        79609      556    606
# ...        ...      ...    ...
# 1790     74116      146    183
# 1791    130717       55     76
# 1792    107064     1744   1770
# 1793     42868      116    135
# 1794   1159073      406    441
#
#                                                  a_text  \
# 0     Microsoft encouraged users to upgrade to IE8, ...
# 1     President Obama for instance, received more mo...
# 2     In defense of the actions, Rod McInnis, the so...
# 3     In response to the outbreak the FDA deployed a...
# 4     * 'Red Sox 5, Devil Rays 4':  B.J. Upton hit a...
# ...                                                 ...
# 1790  Finding water on this planet implies that othe...
# 1791  The second bomb killed three young boys, in th...
# 1792  NASA Associate Administrator for Space Operati...
# 1793  The Argentines had scored first when an in-swi...
# 1794  Although UK-wide legislation, the law is inter...
#
#                                            a_url  \
# 0      https://en.wikinews.org/wiki?curid=148545
# 1      https://en.wikinews.org/wiki?curid=320196
# 2      https://en.wikinews.org/wiki?curid=130602
# 3      https://en.wikinews.org/wiki?curid=201658
# 4       https://en.wikinews.org/wiki?curid=79609
# ...                                          ...
# 1790    https://en.wikinews.org/wiki?curid=74116
# 1791   https://en.wikinews.org/wiki?curid=130717
# 1792   https://en.wikinews.org/wiki?curid=107064
# 1793    https://en.wikinews.org/wiki?curid=42868
# 1794  https://en.wikinews.org/wiki?curid=1159073
#
#                                                 a_title  \
# 0     France, Germany officials warn against using I...
#
#                                            b_categories
# 0     Science and technology,Mozilla,Microsoft,Inter...
# 1     United States,Politics and conflicts,Mississip...
# 2     Science and technology,United States,Environme...
# 3     Asia,Philippines,Biology,Disease,Infectious di...
# 4     Sports,Baseball,Major League Baseball,United S...
# ...                                                 ...
# 1790  California,Astronomy,United States,Science and...
# 1791  Afghanistan,Poland,Politics and conflicts,Afgh...
# 1792  International Space Station,Space Shuttle Disc...
# 1793  Saudi Arabia,Egypt,Uruguay,Luis Suárez,Denis C...
# 1794  Europe,United Kingdom,Scotland,Crime and law,H...
#
# [1795 rows x 14 columns]

# %% [markdown]
# ## Load Typesystem

# %%
from cassis import *
import numpy as np

with open('typesystem.xml', 'rb') as f:
    typesystem = load_typesystem(f)

# %% [markdown]
# ## Create CAS & Sofa

# %%
# This creates automatically the view `_InitialView`
cas = Cas(typesystem=typesystem)

# Sentence Annotation Type
Sentence = typesystem.get_type('webanno.custom.Sentence')
SentenceRelation = typesystem.get_type('webanno.custom.SentenceRelation')

# Creating Sentence Annotation & Sofa
sofa = ""
# Store Sentence generated IDs
alreadyIncludedSentences = []

def createId(doc_id, sent_start, sent_end):
    return "doc_" + str(doc_id) + "_start_" + str(sent_start) + "_end_" + str(sent_end)

# get Sentence Annotation by id
def searchForSentenceAnnotation(id):
    global cas
    for s in cas.select('webanno.custom.Sentence'):
        if s.sent_id == id:
            return s

relations = []
def createAnnotation_pairInput(x):
    global cas
    global relations
    # Add Sentence to Sofa & remember begin & end
    def createAnnotation(doc_id, sent_start, sent_end, text, url, title):
        global sofa
        global cas
        internalID = createId(doc_id, sent_start, sent_end)
        # If Sentence Annotation is not already created, create and add to CAS
        if internalID not in alreadyIncludedSentences:
            b = len(sofa)
            e = len(sofa + text)
            sofa += text
            alreadyIncludedSentences.append(internalID)
            cas.add_annotation(Sentence(begin=b, end=e, doc_id=doc_id, sent_id=internalID, sent_start=sent_start, sent_end=sent_end, url=url, title=title))
        return internalID            
    # apply for both sentences
    id1 = createAnnotation(x["a_doc_id"], x["a_start"], x["a_end"], x["a_text"], x["a_url"], x["a_title"])
    id2 = createAnnotation(x["b_doc_id"], x["b_start"], x["b_end"], x["b_text"], x["b_url"], x["b_title"])
    sent1 = searchForSentenceAnnotation(id1)
    sent2 = searchForSentenceAnnotation(id2)
    # create Relation Annotation
    relations.append(SentenceRelation(begin=sent1.begin, end=sent1.end, Dependent=sent1, Governor=sent2, label="unset"))
    relations.append(SentenceRelation(begin=sent2.begin, end=sent2.end, Dependent=sent2, Governor=sent1, label="unset"))
    
segments.apply(createAnnotation_pairInput, axis=1)

cas.sofa_string = sofa
cas.sofa_mime = "text/plain"

# Save changes to cas
for relation in relations:
    cas.add_annotation(relation)

# %% [markdown]
# ## Save

# %%
cas.to_xmi(output_path)
